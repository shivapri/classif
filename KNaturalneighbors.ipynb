# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import chart_studio.plotly as py

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.9.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('1year.csv')

# %%
data
# Out:
#      net profit total liabilities working capital current assets Attribute5  \
# 0       0.20055           0.37951         0.39641         2.0472     32.351
# 1       0.20912           0.49988         0.47225         1.9447     14.786
# 2       0.24866           0.69592         0.26713         1.5548    -1.1523
# 3      0.081483           0.30734         0.45879         2.4928     51.952
# 4       0.18732           0.61323          0.2296         1.4063    -7.3128
# ...         ...               ...             ...            ...        ...
# 7022   0.018371            0.4741        -0.13619        0.60839    -18.449
# 7023  -0.013359           0.58354        -0.02265        0.92896    -42.232
# 7024   0.006338           0.50276         0.43923         1.8736     9.7417
# 7025  -0.041643            0.8481        -0.12852        0.57485    -121.92
# 7026   0.014946           0.94648         0.03211         1.0363    -20.581
#
# ...

# %%
data.columns
# Out:
# Index(['net profit', 'total liabilities', 'working capital', 'current assets',
#        'Attribute5', 'retained earnings', 'EBIT', 'book value of equity',
#        'sales', 'equity', '(gp+ei+fe)/total assets',
#        'gross profit / short-term liabilities',
#        '(gross profit + depreciation) / sales',
#        '(gross profit + interest) / total assets',
#        'total liabilities * 365) / (gross profit + depreciation)',
#        '(gross profit + depreciation) / total liabilities',
#        'total assets / total liabilities', 'gross profit / total assets',
#        'gross profit / sales', '(inventory * 365) / sales',
#        'sales (n) / sales (n-1)',
#        'profit on operating activities / total assets', 'net profit / sales',
#        'gross profit (in 3 years) / total assets',
#        '(equity - share capital) / total assets',
#        '(net profit + depreciation) / total liabilities',
#        'profit on operating activities / financial expenses',
# ...

# %%
data.iplot(kind='scatter',x='net profit',y='total liabilities',mode='markers')
# Out:
# <div>
#
#
#             <div id="7f3b4b02-1711-4208-a632-f022fbe5d02f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7f3b4b02-1711-4208-a632-f022fbe5d02f")) {
#                     Plotly.newPlot(
#                         '7f3b4b02-1711-4208-a632-f022fbe5d02f',
# ...

# %%
data.iplot(kind='area',x='net profit',y='output')
# Out:
# <div>
#
#
#             <div id="aee0e85c-638a-4293-aa75-01e977f649b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("aee0e85c-638a-4293-aa75-01e977f649b2")) {
#                     Plotly.newPlot(
#                         'aee0e85c-638a-4293-aa75-01e977f649b2',
# ...

# %%
data.describe()
# Out:
#        (gross profit + depreciation) / sales  gross profit / sales  \
# count                            7027.000000           7027.000000
# mean                                2.093345              0.462392
# std                               159.699448             30.646874
# min                              -607.420000           -622.060000
# 25%                                 0.038073              0.014812
# 50%                                 0.080830              0.049966
# 75%                                 0.144955              0.104500
# max                             13315.000000           2156.800000
#
#        (inventory * 365) / sales  net profit / sales  \
# count               7.027000e+03         7027.000000
# mean                1.162128e+03            0.423610
# std                 9.315822e+04           29.742101
# min                 0.000000e+00         -634.590000
# 25%                 1.708300e+01            0.011253
# ...

# %%
data.groupby('output').mean()['total liabilities - cash) / sales'].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="721732a3-b4cb-47fe-bd37-98152f936ce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("721732a3-b4cb-47fe-bd37-98152f936ce0")) {
#                     Plotly.newPlot(
#                         '721732a3-b4cb-47fe-bd37-98152f936ce0',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "total liabilities - cash) / sales", "orientation": "v", "text": "", "type": "bar", "x": [0, 1], "y": [24.44406177664303, 1.7524885498154987]}],
# ...

# %%
data.groupby('output').describe()['(gross profit + depreciation) / sales']['count'].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="74caa7e4-2560-4333-827b-e8fe6735c002" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("74caa7e4-2560-4333-827b-e8fe6735c002")) {
#                     Plotly.newPlot(
#                         '74caa7e4-2560-4333-827b-e8fe6735c002',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": [0, 1], "y": [6756.0, 271.0]}],
# ...

# %%
data
# Out:
#      net profit total liabilities working capital current assets Attribute5  \
# 0       0.20055           0.37951         0.39641         2.0472     32.351
# 1       0.20912           0.49988         0.47225         1.9447     14.786
# 2       0.24866           0.69592         0.26713         1.5548    -1.1523
# 3      0.081483           0.30734         0.45879         2.4928     51.952
# 4       0.18732           0.61323          0.2296         1.4063    -7.3128
# ...         ...               ...             ...            ...        ...
# 7022   0.018371            0.4741        -0.13619        0.60839    -18.449
# 7023  -0.013359           0.58354        -0.02265        0.92896    -42.232
# 7024   0.006338           0.50276         0.43923         1.8736     9.7417
# 7025  -0.041643            0.8481        -0.12852        0.57485    -121.92
# 7026   0.014946           0.94648         0.03211         1.0363    -20.581
#
# ...

# %%
data.columns
# Out:
# Index(['net profit', 'total liabilities', 'working capital', 'current assets',
#        'Attribute5', 'retained earnings', 'EBIT', 'book value of equity',
#        'sales', 'equity', '(gp+ei+fe)/total assets',
#        'gross profit / short-term liabilities',
#        '(gross profit + depreciation) / sales',
#        '(gross profit + interest) / total assets',
#        'total liabilities * 365) / (gross profit + depreciation)',
#        '(gross profit + depreciation) / total liabilities',
#        'total assets / total liabilities', 'gross profit / total assets',
#        'gross profit / sales', '(inventory * 365) / sales',
#        'sales (n) / sales (n-1)',
#        'profit on operating activities / total assets', 'net profit / sales',
#        'gross profit (in 3 years) / total assets',
#        '(equity - share capital) / total assets',
#        '(net profit + depreciation) / total liabilities',
#        'profit on operating activities / financial expenses',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7027 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7027 non-null   object
#  1   total liabilities                                         7027 non-null   object
#  2   working capital                                           7027 non-null   object
#  3   current assets                                            7027 non-null   object
#  4   Attribute5                                                7027 non-null   object
#  5   retained earnings                                         7027 non-null   object
#  6   EBIT                                                      7027 non-null   object
#  7   book value of equity                                      7027 non-null   object
# ...

# %%
data['net profit'].apply(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-6768ea235546> in <module>
# ----> 1 data['net profit'].apply(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: could not convert string to float: '?'

# %%
pd.to_numeric(data['net profit'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-aa3d03195554> in <module>
# ----> 1 pd.to_numeric(data['net profit'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?" at position 1900

# %%
data.drop(data[data['net profit']=='?'].index,inplace=True)

# %%
data['net profit']= pd.to_numeric(data['net profit'])

# %%
data['total liabilities'] = pd.to_numeric(data['total liabilities'])

# %%
data['working capital'] = pd.to_numeric(data['working capital'])

# %%
data['current assets'] = pd.to_numeric(data['current assets'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-f2c7c7d48307> in <module>
# ----> 1 data['current assets'] = pd.to_numeric(data['current assets'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?" at position 75

# %%
data[data['current assets']=='?']
# Out:
#       net profit  total liabilities  working capital current assets  \
# 75    -34.754000           0.000000          0.00000              ?
# 177    -0.004889           0.798710          0.94984              ?
# 279     0.035972           0.000000          1.00000              ?
# 644     0.000000           0.000000          0.00000              ?
# 1232    0.000000           0.000000          0.00000              ?
# 1411    0.000000          -2.421800          0.00000              ?
# 1677    0.000000           0.000000          0.00000              ?
# 1715    0.000000           0.000000          0.00000              ?
# 1814 -256.890000           0.000000          0.00000              ?
# 1815 -256.890000           0.000000          0.00000              ?
# 2259    0.000000           0.000000          0.00000              ?
# 2434    0.000000           0.000000          0.00000              ?
# 2499    0.000000           0.000000          0.00000              ?
# ...

# %%
pd.to_numeric(data[data['current assets']!='?']['current assets']).mean()
# Out:
# 2.628996287592906

# %%
data[data['current assets']=='?']['current assets'] = '2.628996287592906'

# %%
data['current assets'] = pd.to_numeric(data['current assets'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-f2c7c7d48307> in <module>
# ----> 1 data['current assets'] = pd.to_numeric(data['current assets'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?" at position 75

# %%
data[data['current assets']=='?']['current assets'][75] =2.628996287592906

# %%
def currass(word):
    if word=='?':
        word = '2.628996287592906'
    return word

# %%
data['current assets'] = data['current assets'].apply(currass)

# %%
data['current assets'] = pd.to_numeric(data['current assets'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   object
#  5   retained earnings                                         7024 non-null   object
#  6   EBIT                                                      7024 non-null   object
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['net profit', 'total liabilities', 'working capital', 'current assets',
#        'Attribute5', 'retained earnings', 'EBIT', 'book value of equity',
#        'sales', 'equity', '(gp+ei+fe)/total assets',
#        'gross profit / short-term liabilities',
#        '(gross profit + depreciation) / sales',
#        '(gross profit + interest) / total assets',
#        'total liabilities * 365) / (gross profit + depreciation)',
#        '(gross profit + depreciation) / total liabilities',
#        'total assets / total liabilities', 'gross profit / total assets',
#        'gross profit / sales', '(inventory * 365) / sales',
#        'sales (n) / sales (n-1)',
#        'profit on operating activities / total assets', 'net profit / sales',
#        'gross profit (in 3 years) / total assets',
#        '(equity - share capital) / total assets',
#        '(net profit + depreciation) / total liabilities',
#        'profit on operating activities / financial expenses',
# ...

# %%
data['Attribute5'] = pd.to_numeric(data['Attribute5'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-bde0a112171c> in <module>
# ----> 1 data['Attribute5'] = pd.to_numeric(data['Attribute5'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?" at position 82

# %%
data[data['Attribute5']=='?']
# Out:
#       net profit  total liabilities  working capital  current assets  \
# 82      0.000000            0.21671         0.472790         36.7880
# 267     0.014768            0.46314         0.423010          1.9754
# 309     0.233690            0.52189         0.454750          1.8713
# 1417    0.080250            0.65249         0.015217          1.0234
# 1424    0.064590            0.46311         0.247190          1.7975
# 1919    0.000000            0.65926         0.147600          1.6447
# 3134    0.162970            0.43300         0.101130          1.6972
# 4530    0.195850            0.42688         0.223550          2.4799
#
#      Attribute5 retained earnings       EBIT book value of equity    sales  \
# 82            ?          0.019568  -0.025266               3.6146  0.67244
# 267           ?                 0   0.014768               1.1592   2.8643
# 309           ?          0.028496    0.23369              0.91613   7.1246
# ...

# %%
data['Attribute5']
# Out:
# 0        32.351
# 1        14.786
# 2       -1.1523
# 3        51.952
# 4       -7.3128
#          ...
# 7022    -18.449
# 7023    -42.232
# 7024     9.7417
# 7025    -121.92
# 7026    -20.581
# Name: Attribute5, Length: 7024, dtype: object

# %%
data.head(12)
# Out:
#     net profit  total liabilities  working capital  current assets Attribute5  \
# 0     0.200550           0.379510         0.396410          2.0472     32.351
# 1     0.209120           0.499880         0.472250          1.9447     14.786
# 2     0.248660           0.695920         0.267130          1.5548    -1.1523
# 3     0.081483           0.307340         0.458790          2.4928     51.952
# 4     0.187320           0.613230         0.229600          1.4063    -7.3128
# 5     0.228220           0.497940         0.359690          1.7502    -47.717
# 6     0.111090           0.647440         0.289710          1.4705     2.5349
# 7     0.532320           0.027059         0.705540         53.9540     299.58
# 8     0.009020           0.632020         0.053735          1.1263    -37.842
# 9     0.124080           0.838370         0.142040          1.1694    -91.883
# 10    0.240010           0.443550         0.188350          1.4400    -21.165
# ...

# %%
pd.to_numeric(data[data['Attribute5']!='?']['Attribute5']).mean()
# Out:
# -266.17140453007397

# %%
def att5(word):
    if word=='?':
        word = '-266.17140453007397'
    return word

# %%
data['Attribute5']=data['Attribute5'].apply(att5)

# %%
data['Attribute5'] = pd.to_numeric(data['Attribute5'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   object
#  6   EBIT                                                      7024 non-null   object
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data['retained earnings'] = pd.to_numeric(data['retained earnings'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   object
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data['EBIT'] = pd.to_numeric(data['EBIT'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
[c for c in data.columns if type(c)==object]
# Out:
# []

# %%
objtyp = [c for c in data.columns if c not in data.describe().columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data[data[objtyp[0]]=='?'][objtyp[0]]
# Out:
# 75      ?
# 238     ?
# 279     ?
# 644     ?
# 1232    ?
# 1677    ?
# 1715    ?
# 1814    ?
# 1815    ?
# 2259    ?
# 2434    ?
# 2499    ?
# 2616    ?
# 3908    ?
# 4422    ?
# 4472    ?
# 4516    ?
# 4556    ?
# 5787    ?
# 5913    ?
# 5986    ?
# 6182    ?
# 6293    ?
# Name: book value of equity, dtype: object

# %%
dataobjtyp[0]
# Out:
# 'book value of equity'

# %%
np.mean(pd.to_numeric(data[data[objtyp[0]]!='?'][objtyp[0]]))
# Out:
# 2.6224192671047057

# %%
def bvoe(word):
    if word == '?':
        word = '2.6224192671047057
    return word

# %%
data[objtyp[0]] = data[objtyp[0]].apply(bvoe)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data[objtyp[1]] = pd.to_numeric(data[objtyp[1]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data[objtyp[2]] =pd.to_numeric(data[objtyp[2]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
np.mean(pd.to_numeric(data[data[objtyp[3]]!='?'][objtyp[3]]))
# Out:
# 0.354393198626216

# %%
objtyp[3]
# Out:
# '(gp+ei+fe)/total assets'

# %%
def geft(word):
    if word =='?':
        word =1322.7698925508123
    return word

# %%
data[objtyp[3]] = data[objtyp[3]].apply(geft)

# %%
data[objtyp[3]] = pd.to_numeric(data[objtyp[3]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data[objtyp[4]] = data[objtyp[4]].apply(geft)

# %%
data[objtyp[4]] = pd.to_numeric(data[objtyp[4]])

# %%
fedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
def func(word,t):
    if word=='?':
        word = t
    return word

for i in range(len(objtyp[5:])):
    if '?' in objtyp[i+5]:
        t = np.mean(pd.to_numeric(data[data[objtyp[i+5]]!='?'][objtyp[i+5]]))
        data[objtyp[i+5]] = data[objtyp[i+5]].apply(func,t)
        data[objtyp[i+5]] = pd.to_numeric(data[objtyp[i+5]])

# %%
data[data[objtyp[5]]!='?'][objtyp[5]]
# Out:
# 0         0.24976
# 1         0.25834
# 2         0.30906
# 3        0.092704
# 4         0.18732
#           ...
# 7022     0.018371
# 7023    -0.015036
# 7024     0.012022
# 7025    -0.036795
# 7026      0.01526
# Name: (gross profit + interest) / total assets, Length: 7024, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data[objtyp[5:]]
# Out:
#      (gross profit + interest) / total assets  \
# 0                                     0.24976
# 1                                     0.25834
# 2                                     0.30906
# 3                                    0.092704
# 4                                     0.18732
# ...                                       ...
# 7022                                 0.018371
# 7023                                -0.015036
# 7024                                 0.012022
# 7025                                -0.036795
# 7026                                  0.01526
#
#      total liabilities * 365) / (gross profit + depreciation)  \
# 0                                                497.42
# 1                                                677.96
# 2                                                794.16
# 3                                                917.01
# 4                                                1133.2
# ...                                                 ...
# ...

# %%
data.describe()
# Out:
#         net profit  total liabilities  working capital  current assets  \
# count  7024.000000        7024.000000      7024.000000     7024.000000
# mean      0.034660           0.560215         0.119969        2.628996
# std       4.565504           5.350084         5.275459       13.231842
# min    -256.890000         -72.162000      -440.500000        0.000000
# 25%       0.021182           0.296677         0.026968        1.063950
# 50%       0.075802           0.482960         0.181275        1.505000
# 75%       0.160268           0.680233         0.362548        2.474525
# max      94.280000         441.500000         1.000000     1017.800000
#
#          Attribute5  retained earnings         EBIT        sales       equity  \
# count  7.024000e+03        7024.000000  7024.000000  7024.000000  7024.000000
# mean  -2.661714e+02           0.059712     0.313876     5.554149     1.825832
# std    3.706062e+04           6.051113     8.353274   102.009941    33.836452
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7024 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7024 non-null   float64
#  1   total liabilities                                         7024 non-null   float64
#  2   working capital                                           7024 non-null   float64
#  3   current assets                                            7024 non-null   float64
#  4   Attribute5                                                7024 non-null   float64
#  5   retained earnings                                         7024 non-null   float64
#  6   EBIT                                                      7024 non-null   float64
#  7   book value of equity                                      7024 non-null   object
# ...

# %%
data[objtyp[5]].astype(float)
# Out:
# 0       0.249760
# 1       0.258340
# 2       0.309060
# 3       0.092704
# 4       0.187320
#           ...
# 7022    0.018371
# 7023   -0.015036
# 7024    0.012022
# 7025   -0.036795
# 7026    0.015260
# Name: (gross profit + interest) / total assets, Length: 7024, dtype: float64

# %%
data[data[objtyp[5]]=='?']
# Out:
# Empty DataFrame
# ...

# %%
data[data[objtyp[6]]=='?']
# Out:
#       net profit  total liabilities  working capital  current assets  \
# 4556         0.0                0.0          0.90234        2.628996
#
#       Attribute5  retained earnings  EBIT book value of equity   sales  \
# 4556      7750.6                0.0   0.0   2.6224192671047057  1.4999
#
#       equity  ...      X56  X57      X58 X59     X60       X61  X62 X63  \
# 4556  2.1133  ...  0.33329    0  0.66671   0  28.996  0.086306  0.0   ?
#
#           X64  output
# 4556  0.25274       0
#
# [1 rows x 65 columns]

# %%
data.drop(4556,inplace=True)

# %%
data.shape
# Out:
# (7023, 65)

# %%
np.mean(pd.to_numeric(data[data[objtyp[15]]!='?'][objtyp[15]]))
# Out:
# 1322.7698925508123

# %%
data[objtyp[15]]=data[objtyp[15]].apply(geft)

# %%
data[objtyp[15]]=pd.to_numeric(data[objtyp[15]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7023 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7023 non-null   float64
#  1   total liabilities                                         7023 non-null   float64
#  2   working capital                                           7023 non-null   float64
#  3   current assets                                            7023 non-null   float64
#  4   Attribute5                                                7023 non-null   float64
#  5   retained earnings                                         7023 non-null   float64
#  6   EBIT                                                      7023 non-null   float64
#  7   book value of equity                                      7023 non-null   object
# ...

# %%
data[data[objtyp[16]]=='?']
# Out:
#       net profit  total liabilities  working capital  current assets  \
# 279     0.035972           0.000000         1.000000        2.628996
# 307     0.033612           0.806860         0.193680        1.240200
# 1179    1.310600           0.079467         0.920530       12.584000
# 1850    0.025242           0.874500         0.127490        1.146100
# 2202    0.002813           0.157900         0.683040        7.802700
# 2305   -0.316010           1.057400         0.019372        1.019800
# 2486    0.109180           0.352300         0.690690        3.233000
# 2835    0.191770           0.580850         0.419150        1.721600
# 2887    0.335100           0.583510         0.418990        1.721200
# 2930    0.164860           0.165380         0.615460        4.958500
# 2932    0.224200           0.523850         0.476150        1.908900
# 3261    0.124860           0.715100         0.284900        1.398400
# 3592    0.089021           0.845970         0.190270        1.235000
# ...

# %%
data[objtyp[13]] = pd.to_numeric(data[objtyp[13]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7023 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   net profit                                                7023 non-null   float64
#  1   total liabilities                                         7023 non-null   float64
#  2   working capital                                           7023 non-null   float64
#  3   current assets                                            7023 non-null   float64
#  4   Attribute5                                                7023 non-null   float64
#  5   retained earnings                                         7023 non-null   float64
#  6   EBIT                                                      7023 non-null   float64
#  7   book value of equity                                      7023 non-null   object
# ...

# %%
objtyp[10]
# Out:
# 'sales (n) / sales (n-1)'

# %%
data.describe().columns.shape
# Out:
# (36,)

# %%
data.shape
# Out:
# (7023, 65)

# %%
objtyp = [c for c in data.columns if c not in data.describe().columns]

# %%
for i in range(len(objtyp)):
    data.drop([objtyp[i]],axis=1,inplace=True)

# %%
data.columns.shape
# Out:
# (36,)

# %%
data
# Out:
#       net profit  total liabilities  working capital  current assets  \
# 0       0.200550            0.37951          0.39641         2.04720
# 1       0.209120            0.49988          0.47225         1.94470
# 2       0.248660            0.69592          0.26713         1.55480
# 3       0.081483            0.30734          0.45879         2.49280
# 4       0.187320            0.61323          0.22960         1.40630
# ...          ...                ...              ...             ...
# 7022    0.018371            0.47410         -0.13619         0.60839
# 7023   -0.013359            0.58354         -0.02265         0.92896
# 7024    0.006338            0.50276          0.43923         1.87360
# 7025   -0.041643            0.84810         -0.12852         0.57485
# 7026    0.014946            0.94648          0.03211         1.03630
#
#       Attribute5  retained earnings      EBIT    sales    equity  \
# 0        32.3510           0.388250  0.249760  1.13890  0.504940
# ...

# %%
data.groupby('output').describe()['total liabilities']['max'].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="bde5ebc5-f42e-40bd-92db-13d9380bed97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bde5ebc5-f42e-40bd-92db-13d9380bed97")) {
#                     Plotly.newPlot(
#                         'bde5ebc5-f42e-40bd-92db-13d9380bed97',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "max", "orientation": "v", "text": "", "type": "bar", "x": [0, 1], "y": [21.261, 441.5]}],
# ...

# %%
data.groupby('output').describe()['total liabilities']['min'].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="eb36d8ff-0b0f-4b9b-962a-d9e4705644d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eb36d8ff-0b0f-4b9b-962a-d9e4705644d5")) {
#                     Plotly.newPlot(
#                         'eb36d8ff-0b0f-4b9b-962a-d9e4705644d5',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "min", "orientation": "v", "text": "", "type": "bar", "x": [0, 1], "y": [-72.16199999999999, 0.003824]}],
# ...

# %%
data.columns
# Out:
# Index(['net profit', 'total liabilities', 'working capital', 'current assets',
#        'Attribute5', 'retained earnings', 'EBIT', 'sales', 'equity',
#        '(gp+ei+fe)/total assets', 'gross profit / short-term liabilities',
#        '(gross profit + depreciation) / sales',
#        '(gross profit + depreciation) / total liabilities',
#        'total assets / total liabilities', 'gross profit / total assets',
#        'gross profit / sales', '(inventory * 365) / sales',
#        'sales (n) / sales (n-1)',
#        'profit on operating activities / total assets', 'net profit / sales',
#        'gross profit (in 3 years) / total assets',
#        '(equity - share capital) / total assets',
#        '(net profit + depreciation) / total liabilities',
#        'profit on operating activities / financial expenses',
#        'total liabilities - cash) / sales',
#        '(gross profit + interest) / sales', 'profit on sales / sales',
#        'profit on operating activities / sales',
# ...

# %%
data.groupby('output').describe()['working capital']['count'].iplot('bar')
# Out:
# <div>
#
#
#             <div id="5c0ee67e-79fb-4390-8fcd-79a92254ddab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5c0ee67e-79fb-4390-8fcd-79a92254ddab")) {
#                     Plotly.newPlot(
#                         '5c0ee67e-79fb-4390-8fcd-79a92254ddab',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": [0, 1], "y": [6752.0, 271.0]}],
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7023 entries, 0 to 7026
# Data columns (total 36 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   net profit                                           7023 non-null   float64
#  1   total liabilities                                    7023 non-null   float64
#  2   working capital                                      7023 non-null   float64
#  3   current assets                                       7023 non-null   float64
#  4   Attribute5                                           7023 non-null   float64
#  5   retained earnings                                    7023 non-null   float64
#  6   EBIT                                                 7023 non-null   float64
#  7   sales                                                7023 non-null   float64
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
scalar.fit(data.drop('output',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
standard_feat = scalar.transform(data.drop('output',axis=1))

# %%
standard_feat
# Out:
# array([[ 0.03633447, -0.03379112,  0.05242251, ...,  0.01194402,
#         -0.01194435, -0.01506598],
#        [ 0.03821159, -0.01129238,  0.06679853, ...,  0.01194397,
#         -0.01194624, -0.01498654],
#        [ 0.04687218,  0.02535006,  0.02791654, ...,  0.01195304,
#         -0.01195282, -0.01489994],
#        ...,
#        [-0.00620454, -0.01075407,  0.06053935, ...,  0.01193543,
#         -0.01193575, -0.01516776],
#        [-0.016714  ,  0.0537945 , -0.04708179, ...,  0.0119172 ,
#         -0.01193604, -0.01448952],
#        [-0.00431909,  0.07218301, -0.0166332 , ...,  0.01193599,
#         -0.01193706, -0.01498239]])

# %%
data_feat= pd.DataFrame(standard_feat,columns=data.columns[:-1])

# %%
data_feat
# Out:
#       net profit  total liabilities  working capital  current assets  \
# 0       0.036334          -0.033791         0.052423       -0.043969
# 1       0.038212          -0.011292         0.066799       -0.051716
# 2       0.046872           0.025350         0.027917       -0.081183
# 3       0.010255          -0.047281         0.064247       -0.010293
# 4       0.033437           0.009894         0.020802       -0.092406
# ...          ...                ...              ...             ...
# 7018   -0.003569          -0.016111        -0.048536       -0.152708
# 7019   -0.010519           0.004345        -0.027013       -0.128481
# 7020   -0.006205          -0.010754         0.060539       -0.057089
# 7021   -0.016714           0.053795        -0.047082       -0.155243
# 7022   -0.004319           0.072183        -0.016633       -0.120368
#
#       Attribute5  retained earnings      EBIT     sales    equity  \
# 0       0.008086           0.054292 -0.007681 -0.043288 -0.039036
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_feat

# %%
y=data['output']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#       net profit  total liabilities  working capital  current assets  \
# 2469   -0.007973           0.079123        -0.027612       -0.125095
# 5188    0.064452          -0.054438         0.042196       -0.010633
# 1270    0.022520           0.020515         0.034026       -0.089345
# 3766    0.005884           0.021201        -0.021721       -0.121971
# 3485   -0.012271          -0.038638        -0.029489       -0.132200
# ...          ...                ...              ...             ...
# 599    -0.013191          -0.027062         0.003320       -0.073663
# 5695   -0.007593          -0.021548         0.019362       -0.072726
# 1361    0.008942          -0.077359         0.069189        0.133141
# 1547    0.003407           0.024320        -0.032448       -0.128785
# 4959   -0.002106           0.010083        -0.045279       -0.149792
#
#       Attribute5  retained earnings      EBIT     sales    equity  \
# 2469    0.005641          -0.012642 -0.037775 -0.044597 -0.053814
# ...

# %%
X_test
# Out:
#       net profit  total liabilities  working capital  current assets  \
# 538     0.048208           0.042309        -0.098192       -0.161659
# 4718   -0.001593           0.043858        -0.061247       -0.144642
# 155     0.033842          -0.000109         0.046855       -0.073550
# 5024   -0.003254          -0.019617        -0.019069       -0.119915
# 5992    0.005111           0.026898        -0.037369       -0.133302
# ...          ...                ...              ...             ...
# 6274    0.029722           0.044340         0.016687       -0.069302
# 3795    0.003726          -0.046673         0.033328       -0.051073
# 1539    0.063666          -0.063344         0.055171        0.017156
# 3533    0.012521          -0.035868        -0.018053       -0.117497
# 896    -0.004190           0.050299        -0.033827       -0.128998
#
#       Attribute5  retained earnings      EBIT     sales    equity  \
# 538     0.004198           0.001980 -0.013075 -0.043229 -0.048864
# ...

# %%
y_train.value_counts()
# Out:
# 0    4722
# 1     194
# Name: output, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    2030
# 1      77
# Name: output, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
predictions = knn.predict(X_test)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
print('\n')
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2030
#            1       0.67      0.13      0.22        77
#
#     accuracy                           0.97      2107
#    macro avg       0.82      0.56      0.60      2107
# weighted avg       0.96      0.97      0.95      2107
#
#
#
# [[2025    5]
#  [  67   10]]

# %%
error_rate= []
for i in range(1,60):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i!=y_test))

# %%
np.argmin(error_rate)
# Out:
# 3

# %%
plt.figure(figsize=(18,8))
plt.plot(range(1,60),error_rate,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)
plt.title('error_distribution')
plt.xlabel('n_neighbors')
plt.ylabel('error_rate')
# Out:
# Text(0, 0.5, 'error_rate')

# %%
pd.Series(error_rate).iplot('scatter')
# Out:
# <div>
#
#
#             <div id="526825e8-36e3-47aa-980f-33f6d051c24e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("526825e8-36e3-47aa-980f-33f6d051c24e")) {
#                     Plotly.newPlot(
#                         '526825e8-36e3-47aa-980f-33f6d051c24e',
# ...

# %%
knn_tr = KNeighborsClassifier(n_neighbors=3)

# %%
knn_tr.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
prediction_real = knn_tr.predict(X_test)

# %%
print(classification_report(y_test,prediction_real))
print('\n')
print(confusion_matrix(y_test,prediction_real))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2030
#            1       0.46      0.16      0.23        77
#
#     accuracy                           0.96      2107
#    macro avg       0.72      0.57      0.61      2107
# weighted avg       0.95      0.96      0.95      2107
#
#
#
# [[2016   14]
#  [  65   12]]
